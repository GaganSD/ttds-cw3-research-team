# %%
import pandas as pd
import numpy as np
import os

# %%
# db = pd.read_csv(r"", encoding="utf-8")
path = os.getcwd() + "\edinburghresearchdatasets.xls"
print(path)
db = pd.read_excel(path)
# Out:
# c:\Users\gagan\OneDrive\Desktop\GitHub\ttds-cw3\playground\edinburghresearchdatasets.xls

# %%
db.head(5)
# Out:
#    Rank                                               Name  \
# 0     1  Profiling the Immune Epigenome across Global C...
# 1     2               PacBio HiFi raw data of a Boran bull
# 2     3                   CTLGH BMGF poultry sequence data
# 3     4                                           PeaceFem
# 4     5  Physiological measurements (respiration, calci...
#
#                                                  URL  Unnamed: 3  Unnamed: 4  \
# 0  https://www.research.ed.ac.uk/en/datasets/prof...         NaN         NaN
# 1  https://www.research.ed.ac.uk/en/datasets/pacb...         NaN         NaN
# 2  https://www.research.ed.ac.uk/en/datasets/ctlg...         NaN         NaN
# 3  https://www.research.ed.ac.uk/en/datasets/peac...         NaN         NaN
# 4  https://www.research.ed.ac.uk/en/datasets/phys...         NaN         NaN
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
try:
    db.drop(['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], axis=1, inplace=True)
except:
    print("couldn't drop default irelevant columns")

# %%
db.head(5)
# Out:
#    Rank                                               Name  \
# 0     1  Profiling the Immune Epigenome across Global C...
# 1     2               PacBio HiFi raw data of a Boran bull
# 2     3                   CTLGH BMGF poultry sequence data
# 3     4                                           PeaceFem
# 4     5  Physiological measurements (respiration, calci...
#
#                                                  URL
# 0  https://www.research.ed.ac.uk/en/datasets/prof...
# 1  https://www.research.ed.ac.uk/en/datasets/pacb...
# 2  https://www.research.ed.ac.uk/en/datasets/ctlg...
# 3  https://www.research.ed.ac.uk/en/datasets/peac...
# 4  https://www.research.ed.ac.uk/en/datasets/phys...

# %%
for index, row in db.iterrows():
    print(row['Rank'], row['Name'], row['URL'])
# Out:
# 1 Profiling the Immune Epigenome across Global Cattle Breeds https://www.research.ed.ac.uk/en/datasets/profiling-the-immune-epigenome-across-global-cattle-breeds
# 2 PacBio HiFi raw data of a Boran bull https://www.research.ed.ac.uk/en/datasets/pacbio-hifi-raw-data-of-a-boran-bull
# 3 CTLGH BMGF poultry sequence data https://www.research.ed.ac.uk/en/datasets/ctlgh-bmgf-poultry-sequence-data
# 4 PeaceFem https://www.research.ed.ac.uk/en/datasets/peacefem
# 5 Physiological measurements (respiration, calcification, ammonia excretion) from laboratory experiments on the effects of temperature and ocean acidification stressors on Desmophyllum dianthus https://www.research.ed.ac.uk/en/datasets/physiological-measurements-respiration-calcification-ammonia-excr
# 6 A comparative platform for strain typing CWD https://www.research.ed.ac.uk/en/datasets/a-comparative-platform-for-strain-typing-cwd
# 7 Understanding Water Resources, Governance, and Meanings in Rural Belize, 2017-2018 https://www.research.ed.ac.uk/en/datasets/understanding-water-resources-governance-and-meanings-in-rural-be
# 8 APP NL/F - 1 year rodent EEG and video recordings. Cerebellum reference https://www.research.ed.ac.uk/en/datasets/app-nlf-1-year-rodent-eeg-and-video-recordings-cerebellum-referen
# 9 APP NL/F - 1 year rodent EEG and video recordings. Cerebellum reference. Donepezil administration https://www.research.ed.ac.uk/en/datasets/app-nlf-1-year-rodent-eeg-and-video-recordings-cerebellum-referen-2
# 10 Matlab codes for "Refined Composite Multivariate Generalized Multiscale Fuzzy Entropy: A Tool for Complexity Analysis of Multichannel Signals" https://www.research.ed.ac.uk/en/datasets/matlab-codes-for-refined-composite-multivariate-generalized-multi
# 11 Gaelic POS tagger and tokeniser https://www.research.ed.ac.uk/en/datasets/gaelic-pos-tagger-and-tokeniser
# 12 Native MS Analysis of Encapsulated Ferritin from Rhodospirillum rubrum https://www.research.ed.ac.uk/en/datasets/native-ms-analysis-of-encapsulated-ferritin-from-rhodospirillum-r
# 13 APP NL/F - 8 month rodent EEG and video recordings https://www.research.ed.ac.uk/en/datasets/app-nlf-8-month-rodent-eeg-and-video-recordings
# 14 RNASeq project 850N https://www.research.ed.ac.uk/en/datasets/rnaseq-project-850n
# 15 RNASeq project 1032N https://www.research.ed.ac.uk/en/datasets/rnaseq-project-1032n
# 16 gDNA Seq project 2366N https://www.research.ed.ac.uk/en/datasets/gdna-seq-project-2366n
# 17 Listening test materials for "Waveform generation based on signal reshaping for statistical parametric speech synthesis" https://www.research.ed.ac.uk/en/datasets/listening-test-materials-for-waveform-generation-based-on-signal-
# 18 An Order of the Outside https://www.research.ed.ac.uk/en/datasets/an-order-of-the-outside
# 19 RNASeq project 818N https://www.research.ed.ac.uk/en/datasets/rnaseq-project-818n
# 20 Listening test materials for "A template-based approach for speech synthesis intonation generation using LSTMs https://www.research.ed.ac.uk/en/datasets/listening-test-materials-for-a-template-based-approach-for-speech
# 21 Shilluk_2016_controlled_ThreeLevelVowelLength https://www.research.ed.ac.uk/en/datasets/shilluk2016controlledthreelevelvowellength-2
# 22 Roslin Institute archival data from former staff etc https://www.research.ed.ac.uk/en/datasets/roslin-institute-archival-data-from-former-staff-etc
# 23 The Voice Conversion Challenge 2016 https://www.research.ed.ac.uk/en/datasets/the-voice-conversion-challenge-2016
# 24 J20 rodent EEG and video recordings https://www.research.ed.ac.uk/en/datasets/j20-rodent-eeg-and-video-recordings
# 25 Tone-melody correspondence in Vietnamese popular song: supplementary materials https://www.research.ed.ac.uk/en/datasets/tone-melody-correspondence-in-vietnamese-popular-song-supplementa

# %%
db.size
# Out:
# 75

# %%
db
# Out:
#     Rank                                               Name  \
# 0      1  Profiling the Immune Epigenome across Global C...
# 1      2               PacBio HiFi raw data of a Boran bull
# 2      3                   CTLGH BMGF poultry sequence data
# 3      4                                           PeaceFem
# 4      5  Physiological measurements (respiration, calci...
# 5      6       A comparative platform for strain typing CWD
# 6      7  Understanding Water Resources, Governance, and...
# 7      8  APP NL/F - 1 year rodent EEG and video recordi...
# 8      9  APP NL/F - 1 year rodent EEG and video recordi...
# 9     10  Matlab codes for "Refined Composite Multivaria...
# 10    11                    Gaelic POS tagger and tokeniser
# 11    12  Native MS Analysis of Encapsulated Ferritin fr...
# 12    13  APP NL/F - 8 month rodent EEG and video record...
# 13    14                                RNASeq project 850N
# 14    15                               RNASeq project 1032N
# 15    16                             gDNA Seq project 2366N
# 16    17  Listening test materials for "Waveform generat...
# 17    18                            An Order of the Outside
# 18    19                                RNASeq project 818N
# 19    20  Listening test materials for "A template-based...
# 20    21      Shilluk_2016_controlled_ThreeLevelVowelLength
# 21    22  Roslin Institute archival data from former sta...
# 22    23                The Voice Conversion Challenge 2016
# 23    24                J20 rodent EEG and video recordings
# 24    25  Tone-melody correspondence in Vietnamese popul...
#
#                                                   URL
# 0   https://www.research.ed.ac.uk/en/datasets/prof...
# 1   https://www.research.ed.ac.uk/en/datasets/pacb...
# 2   https://www.research.ed.ac.uk/en/datasets/ctlg...
# 3   https://www.research.ed.ac.uk/en/datasets/peac...
# 4   https://www.research.ed.ac.uk/en/datasets/phys...
# 5   https://www.research.ed.ac.uk/en/datasets/a-co...
# 6   https://www.research.ed.ac.uk/en/datasets/unde...
# 7   https://www.research.ed.ac.uk/en/datasets/app-...
# 8   https://www.research.ed.ac.uk/en/datasets/app-...
# 9   https://www.research.ed.ac.uk/en/datasets/matl...
# 10  https://www.research.ed.ac.uk/en/datasets/gael...
# 11  https://www.research.ed.ac.uk/en/datasets/nati...
# 12  https://www.research.ed.ac.uk/en/datasets/app-...
# 13  https://www.research.ed.ac.uk/en/datasets/rnas...
# 14  https://www.research.ed.ac.uk/en/datasets/rnas...
# 15  https://www.research.ed.ac.uk/en/datasets/gdna...
# 16  https://www.research.ed.ac.uk/en/datasets/list...
# 17  https://www.research.ed.ac.uk/en/datasets/an-o...
# 18  https://www.research.ed.ac.uk/en/datasets/rnas...
# 19  https://www.research.ed.ac.uk/en/datasets/list...
# 20  https://www.research.ed.ac.uk/en/datasets/shil...
# 21  https://www.research.ed.ac.uk/en/datasets/rosl...
# 22  https://www.research.ed.ac.uk/en/datasets/the-...
# 23  https://www.research.ed.ac.uk/en/datasets/j20-...
# 24  https://www.research.ed.ac.uk/en/datasets/tone...

# %%
from json.tool import main
import urllib.request as _urllib
import pandas as pd
import numpy as np
import os




class Parser:

    def __init__(self):
        self.default_url = "https://www.research.ed.ac.uk/en/datasets/"
        self.url_prefix = "?format=&page="
        self.url_suffix = "export=xls"
        self.ed_research_repo_path = None


    def ed_research_get_repo(self, new_url=""):

        if new_url:
            url = new_url
        else: url = self.default_url

        # url_extension = 

        final_url = url + self.url_prefix + str(0) + self.url_suffix
        print(1)
        # try:
        _urllib.urlretrieve(final_url, '\ed_re_1.xls')
        print(final_url)
        path = os.getcwd() + "\ed_re_1.xls"

        # self.ed_research_repo_path = path 
        dataset = pd.read_excel(path)

        print("Dataset Downloaded.")
        print(dataset.columns)


    def ed_research_print_all(self):

        if not self.ed_research_repo_path:
            print("Update variable 'ed_research_repo_path' with path")
            return None
        
        dataset = pd.read_excel(self.ed_research_repo_path)


# print(22)
curr_parser = Parser()
curr_parser.ed_research_get_repo()
# Out:
# 1
# https://www.research.ed.ac.uk/en/datasets/?format=&page=0export=xls
# Dataset Downloaded.
# Index(['Rank', 'Name', 'URL', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], dtype='object')
