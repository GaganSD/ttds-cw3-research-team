# %%
import pandas as pd
import numpy as np

kaggle_df = pd.read_csv('kaggle_dataset_df_page500.csv')
print(kaggle_df.shape[0])
kaggle_df
# Out:
# 9498
#                                                   title  \
# 0                              The Bachelor Contestants
# 1                                        Mineral photos
# 2                                       Deepwater Ports
# 3                                 ubiquant_train_target
# 4                                  easy_firefly_weights
# ...                                                 ...
# 9493                Stanford Earthquake Dataset (STEAD)
# 9494                                     Asphalt Cracks
# 9495                          Maternal Health Risk Data
# 9496       Medical Personal Protective Equipment Images
# 9497   Higher Education Students Performance Evaluation
#
#                                                subtitle  \
# 0     This dataset contains information about past s...
# 1     +39,000 images of mineral stored in 15 categories
# 2     A Dataset of the Deepwater Port Licensing Program
# ...

# %%
paperwithcode_df = pd.read_csv('paperwithcode_df.csv')
print(paperwithcode_df.shape[0])
paperwithcode_df
# Out:
# 5627
#                                                   title  \
# 0                                                 MNIST
# 1                                                CelebA
# 2                                              JFT-300M
# 3                                                  GLUE
# 4                                              MultiNLI
# ...                                                 ...
# 5622  Dataset for the Article "Does the Venue of Sci...
# 5623                           WSJ Dow Jones Stock Data
# 5624                                               ZInd
# 5625                                         IMDB-Clean
# 5626            TriggerCit 2021 Thailand / Nepal floods
#
#                                             description  \
# 0     The **MNIST** database (**Modified National In...
# 1     CelebFaces Attributes dataset contains 202,599...
# 2     **JFT-300M** is an internal Google dataset use...
# ...

# %%
! ls result
# Out:
# paper_bm_25_result_df_covid_2021.csv
# paper_bm_25_result_df_heart_disease.csv
# paper_bm_25_result_df_pose_estimation.csv
# paper_bm_25_result_df_recognition_deep.csv
# paper_bm_25_result_df_review_food.csv
# paper_bm_25_result_df_sound_transformer.csv
# paper_bm_25_result_df_statist_health.csv
# paper_bm_25_result_df_statistics_health.csv
# paper_bm_25_result_df_stock_predict.csv
# paper_bm_25_result_df_stock_prediction.csv
# paper_bm_25_result_df_vision_transform.csv
# paper_tfidf_result_df_covid_2021.csv
# paper_tfidf_result_df_heart_disease.csv
# paper_tfidf_result_df_pose_estimation.csv
# paper_tfidf_result_df_recognition_deep.csv
# paper_tfidf_result_df_review_food.csv
# paper_tfidf_result_df_sound_transformer.csv
# paper_tfidf_result_df_statist_health.csv
# paper_tfidf_result_df_statistics_health.csv
# paper_tfidf_result_df_stock_predict.csv
# paper_tfidf_result_df_stock_prediction.csv
# paper_tfidf_result_df_vision_transform.csv
# phrase_result_df_2021_covid.csv
# ...

# %%
bm25_res = pd.read_csv('result/paper_bm_25_result_df_stock_predict.csv')
tfidf_res = pd.read_csv('result/paper_tfidf_result_df_stock_predict.csv')
for i in range(10):
    print(bm25_res.iloc[i, 0])
print()
for i in range(10):
    print(tfidf_res.iloc[i, 0])
# Out:
# The influence of food competition and host specificity on the transmission of Triaenophorus crassus (Cestoda) and Cystidicola farionis (Nematoda) to Coregonus lavaretus and Coregonus albula (Pisces:Coregonidae) in Finland.
# Wall Street's assessment of plastic surgery--related technology: a clinical and financial analysis.
# Carbon and nitrogen fluxes in a closed seawater facility.
# A predictable and accurate technique with elastomeric impression materials.
# Betting on the future: the virtues of contingent contracts.
# Sexuality and genetic identity in the Agaricus section Arvenses.
# Validity of the examination method of occlusal contact pattern relating to mandibular position.
# An experimental analysis of territory size in juvenile steelhead trout.
# X-linked transmission of the shaker mutation in rats with hereditary Purkinje cell degeneration and ataxia.
# Improved conditioned avoidance learning by oxytocin administration in high-emotional male Sprague-Dawley rats.
#
# ...

# %%
bm25_res = pd.read_csv('result/paper_bm_25_result_df_vision_transform.csv')
tfidf_res = pd.read_csv('result/paper_tfidf_result_df_vision_transform.csv')
for i in range(10):
    print(bm25_res.iloc[i, 0])
print()
for i in range(10):
    print(tfidf_res.iloc[i, 0])
# Out:
# Texture-Based Methods for Analyzing Elementary Visual Substances.
# Curvature of visual space under vertical eye rotation: implications for spatial vision and visuomotor control.
# Adaptive filtering in spatial vision: evidence from feature marking in plaids.
# The myth of upright vision. A psychophysical and functional imaging study of adaptation to inverting spectacles.
# Achieving results through transformational leadership.
# Seeing in three dimensions: the neurophysiology of stereopsis.
# Hospital transformation and organisational learning.
# Asymmetric color matching: how color appearance depends on the illuminant.
# Saving your career in the 21st century.
# The importance of vitamin A in nutrition.
#
# Texture-Based Methods for Analyzing Elementary Visual Substances.
# Transformation of Acetobacter xylinum with plasmid DNA by electroporation.
# Curvature of visual space under vertical eye rotation: implications for spatial vision and visuomotor control.
# ...

# %%
phrase_df = pd.read_csv('result/phrase_result_df_stock_predict.csv')
for i in range(10):
    print(phrase_df.iloc[i, 0])
    
print()
phrase_df = pd.read_csv('result/phrase_result_df_vision_transform.csv')
for i in range(10):
    print(phrase_df.iloc[i, 0])
# Out:
# A Novel Ensemble Deep Learning Model for Stock Prediction Based on Stock
#   Prices and News
# Measuring Financial Time Series Similarity With a View to Identifying
#   Profitable Stock Market Opportunities
# A Word is Worth A Thousand Dollars: Adversarial Attack on Tweets Fools Stock Prediction
# Stock trend prediction using news sentiment analysis
# Stock Index Prediction with Multi-task Learning and Word Polarity Over
#   Time
# The epidemiology of hip fractures and methods of prevention.
# HATS: A Hierarchical Graph Attention Network for Stock Movement
#   Prediction
# Improving Nonparametric Classification via Local Radial Regression with
#   an Application to Stock Prediction
# Trade the Event: Corporate Events Detection for News-Based Event-Driven
#   Trading
# Exploiting Social Relations and Sentiment for Stock Prediction
#
# Learning Robust and Lightweight Model through Separable Structured
#   Transformations
# Vision Transformer for femur fracture classification
# ...
