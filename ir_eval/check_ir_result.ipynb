# %%
import pandas as pd
import numpy as np

kaggle_df = pd.read_csv('kaggle_dataset_df_page500.csv')
print(kaggle_df.shape[0])
kaggle_df
# Out:
# 9498
#                                                   title  \
# 0                              The Bachelor Contestants
# 1                                        Mineral photos
# 2                                       Deepwater Ports
# 3                                 ubiquant_train_target
# 4                                  easy_firefly_weights
# ...                                                 ...
# 9493                Stanford Earthquake Dataset (STEAD)
# 9494                                     Asphalt Cracks
# 9495                          Maternal Health Risk Data
# 9496       Medical Personal Protective Equipment Images
# 9497   Higher Education Students Performance Evaluation
#
#                                                subtitle  \
# 0     This dataset contains information about past s...
# 1     +39,000 images of mineral stored in 15 categories
# 2     A Dataset of the Deepwater Port Licensing Program
# ...

# %%
paperwithcode_df = pd.read_csv('paperwithcode_df.csv')
print(paperwithcode_df.shape[0])
paperwithcode_df
# Out:
# 5627
#                                                   title  \
# 0                                                 MNIST
# 1                                                CelebA
# 2                                              JFT-300M
# 3                                                  GLUE
# 4                                              MultiNLI
# ...                                                 ...
# 5622  Dataset for the Article "Does the Venue of Sci...
# 5623                           WSJ Dow Jones Stock Data
# 5624                                               ZInd
# 5625                                         IMDB-Clean
# 5626            TriggerCit 2021 Thailand / Nepal floods
#
#                                             description  \
# 0     The **MNIST** database (**Modified National In...
# 1     CelebFaces Attributes dataset contains 202,599...
# 2     **JFT-300M** is an internal Google dataset use...
# ...

# %%
! ls
# Out:
# __pycache__                     paperwithcode_df.csv
# bm_25_result_df_covid_2021.csv  preprocessing.py
# bm_25_result_df_review_food.csv ranking.py
# check_ir_result.ipynb           ranking_paper.py
# index_generator.py              result
# index_generator_mongodb.py      result.log
# kaggle_dataset_df_page500.csv   tfidf_result_df_covid_2021.csv
# last.pickle                     tfidf_result_df_review_food.csv

# %%
bm25_res_covid_2021 = pd.read_csv('result/paper_bm_25_result_df_covid_2021.csv')
tfidf_res_covid_2021 = pd.read_csv('result/paper_tfidf_result_df_covid_2021.csv')
bm25_res_covid_2021
# Out:
#                                                title  \
# 0     FINTOC 2021 - Document Structure Understanding
# 1            T5-LONG-EXTRACT at FNS-2021 Shared Task
# 2  NVJPFSI at FinCausal 2021 Span-based Causality...
# 3  The Financial Narrative Summarisation Shared T...
# 4  The Financial Document Causality Detection Sha...
# 5  ISPRAS@FinTOC-2021 Shared Task: Two-stage TOC ...
# 6  The Financial Document Structure Extraction Sh...
# 7  Method Towards CVPR 2021 Image Matching Challenge
# 8  Method Towards CVPR 2021 Image Matching Challenge
# 9  German Abusive Language Dataset with Focus on ...
#
#                                             abstract  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# ...

# %%
tfidf_res_covid_2021
# Out:
#                                                title  \
# 0  Explainable AI Framework for COVID-19 Predicti...
# 1  Acceptance of COVID-19 Vaccine and Its Determi...
# 2  Acceptance of COVID-19 Vaccine and Its Determi...
# 3  MMCoVaR: Multimodal COVID-19 Vaccine Focused D...
# 4  Projecting the Impact of Covid-19 Variants and...
# 5  Projecting the Impact of Covid-19 Variants and...
# 6  Projecting the Impact of Covid-19 Variants and...
# 7  Bayesian hypothesis testing and hierarchical m...
# 8  Bayesian hypothesis testing and hierarchical m...
# 9  COVID-19 Diagnosis from Cough Acoustics using ...
#
#                                             abstract                id
# 0    In 2020, covid-19 virus had reached more tha...  arxiv-2201.06997
# 1    Background: Bangladesh govt. launched a nati...  arxiv-2103.15206
# 2    Background: Bangladesh govt. launched a nati...  arxiv-2103.15206
# 3    The outbreak of COVID-19 has resulted in an ...  arxiv-2109.06416
# ...

# %%
for i in range(10):
    print(tfidf_res_covid_2021.iloc[i,0])
# Out:
# Explainable AI Framework for COVID-19 Prediction in Different Provinces
#   of India
# Acceptance of COVID-19 Vaccine and Its Determinants in Bangladesh
# Acceptance of COVID-19 Vaccine and Its Determinants in Bangladesh
# MMCoVaR: Multimodal COVID-19 Vaccine Focused Data Repository for Fake
#   News Detection and a Baseline Architecture for Classification
# Projecting the Impact of Covid-19 Variants and Vaccination Strategies in
#   Disease Transmission using a Multilayer Network Model in Costa Rica
# Projecting the Impact of Covid-19 Variants and Vaccination Strategies in
#   Disease Transmission using a Multilayer Network Model in Costa Rica
# Projecting the Impact of Covid-19 Variants and Vaccination Strategies in
#   Disease Transmission using a Multilayer Network Model in Costa Rica
# Bayesian hypothesis testing and hierarchical modelling of ivermectin
#   effectiveness in treating Covid-19
# Bayesian hypothesis testing and hierarchical modelling of ivermectin
# ...

# %%
for i in range(10):
    print(tfidf_res_covid_2021.iloc[i,-1])
# Out:
# arxiv-2201.06997
# arxiv-2103.15206
# arxiv-2103.15206
# arxiv-2109.06416
# arxiv-2109.11425
# arxiv-2109.11425
# arxiv-2109.11425
# arxiv-2109.13739
# arxiv-2109.13739
# arxiv-2110.06123

# %%
bm25_res_review_food = pd.read_csv('result/paper_bm_25_result_df_review_food.csv')
tfidf_res_review_food = pd.read_csv('result/paper_tfidf_result_df_review_food.csv')
bm25_res_review_food
# Out:
#                                                title  \
# 0  Anaphylaxis after ingestion of carmine colored...
# 1  Ruchi: Rating Individual Food Items in Restaur...
# 2  Position of the American Dietetic Association:...
# 3      Food ads on TV: a health hazard for children?
# 4  Food allergy: when and how to perform oral foo...
# 5  Food conditioning is impaired in cats deprived...
# 6                                       Book Review:
# 7  Diet self-selection and food hoarding after fo...
# 8  Intracerebroventricular injection of orexins d...
# 9  Response to changes in food palatability in tu...
#
#                                             abstract
# 0  Two patients with adverse food reactions to fo...
# 1                                                NaN
# 2  Food irradiation has been identified a sa safe...
# 3  OBJECTIVE\nTo examine the nutritional quality ...
# 4  In many situations, the diagnosis of food alle...
# 5  Cats were fed by stomach tube during the first...
# ...

# %%
tfidf_res_review_food
# Out:
#                                                title  \
# 0      Encapsulation in the food industry: a review.
# 1  Does nutritionist review of a self-administere...
# 2  Dose-response in double-blind, placebo-control...
# 3  The application of in vitro data in the deriva...
# 4  Microbiological safety evaluations and recomme...
# 5  Introduction to the reviews on peptides and th...
# 6  Rate of intake, bites, and chews-the interpret...
# 7  Dietary determinants of energy intake and weig...
# 8  The role of enterostatin and apolipoprotein AI...
# 9  When will the stork arrive? Patterns of birth ...
#
#                                             abstract
# 0  Encapsulation involves the incorporation of fo...
# 1  OBJECTIVE\nThis study sought to evaluate the b...
# 2  BACKGROUND\nDouble-blind, placebo-controlled o...
# 3  The acceptable daily intake (ADI) for food add...
# 4  In 1997, the National Advisory Committee on Mi...
# 5  The progress in the identification of peripher...
# ...
